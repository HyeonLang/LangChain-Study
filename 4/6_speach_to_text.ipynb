# %% [markdown]
# #OpenAi API 사전 준비

# %%
# !pip install openai==0.27.4

import openai
openai.api_key = "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"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 1.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %% [markdown]
# # 음성 텍스트 변환

# %%
import openai

#음성 텍스트 변환 (현재폴더에 오디오 업로드 필요)
audio_file = open("audio.mp3", "rb")
transscript = openai.Audio.transcribe("whisper-1", audio_file)
print(transscript["text"])
# Out:
# Whisper는 범위온 음성인식 모델입니다. 다양한 오디오의 대규모 데이터 시트를 학습하고 다국어 음성인식, 음성번역, 언어식별을 수행할 수 있는 멀티태스킹 모델이기도 합니다.

# %% [markdown]
# # 음성을 영어로 번역해서 텍스트 변환

# %%
import openai

#음성을 영어로 번역하고 텍스트로 변환 (현재폴더에 오디오 업로드 필요)
audio_file = open("audio.mp3", "rb")
transscript = openai.Audio.translate("whisper-1", audio_file)
print(transscript["text"])
# Out:
# Whisper is a multi-tasking model that can learn a large set of audio data sets and perform multi-language voice recognition, voice translation, and language recognition.

# %% [markdown]
# # 더 긴 오디오 파일 번역

# %%
# !pip install pydub

# %%
#25mb 이상 (음악파일 필요)
from pydub import AudioSegment

song = AudioSegment.from_mp3("good_morning.mp3")
ten_minutes = 10 * 60 *1000
first_10_minutes = song[:ten_minutes]
first_10_minutes.export("good_morning_10.mp3",format="mp3")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-7ae9e7f5dffb> in <cell line: 4>()
#       2 from pydub import AudioSegment
#       3
# ----> 4 song = AudioSegment.from_mp3("good_morning.mp3")
#       5 ten_minutes = 10 * 60 *1000
#       6 first_10_minutes = song[:ten_minutes]
#
# /usr/local/lib/python3.10/dist-packages/pydub/audio_segment.py in from_mp3(cls, file, parameters)
#     794     @classmethod
#     795     def from_mp3(cls, file, parameters=None):
# --> 796         return cls.from_file(file, 'mp3', parameters=parameters)
#     797
#     798     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/pydub/audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     649         except TypeError:
#     650             filename = None
# ...
