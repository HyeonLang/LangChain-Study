# %% [markdown]
# # OpenAI API 사전 준비

# %%
#패키지 설치
# !pip install tiktoken
# !pip install cohere
# !pip install openai

# %%
#환경변수 준비
import openai
openai.api_key = "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"

# %% [markdown]
# # 텍스트 생성

# %%
#프롬프트 준비
prompt = '''다음 이야기를 써주세요.
기타를 좋아하지만 컴맹인 여고생이 어떤 계기로 록밴드에 가입하고, 낯선 인간관계를 통해 활동하게 되는 이야기.'''

# %%
import openai

openai.api_key = "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"
#텍스트 생성 실행
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0.7,
    max_tokens=500
)
print(response["choices"][0]["text"])
# Out:
# 바쁜 고등학교 생활을 타파하고 있던 여고생 사라는 기타를 좋아하고 자신의 꿈을 실현하고 싶어 했습니다. 그녀는 친구에게 소개받은 록밴드에 가입을 하기로 결심했습니다. 그녀는 반갑게 맞아주고 환영해 주는 멤버들에게 감사하며 반가운 느낌으로 록밴드에서 활동하기 시작했습니다. 그 이후 록밴드에서 사라는 새로운 밴드 멤버로서 점점 자신감을 갖고 자신의 꿈을 이루어가기 시작했습니다.

# %% [markdown]
# # 질의응답

# %%
#프롬프트 준비
prompt = "인공지능에 대해 알려주세요."

# %%
import openai

#텍스트 생성 실행
#텍스트 생성 실행
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0,
    max_tokens=500
)
print(response["choices"][0]["text"])
# Out:
# 인공지능(Artificial Intelligence, AI)은 인간의 지능을 모방하는 컴퓨터 기술을 말합니다. 인공지능은 인간의 지능과 비슷한 방식으로 문제를 해결하고, 인간이 수행하는 다양한 작업을 자동화하는 데 사용됩니다. 인공지능은 인간의 지능을 모방하기 위해 다양한 알고리즘과 기술을 사용합니다. 인공지능은 인간의 지능을 모방하기 위해 다양한 알고리즘과 기술을 사용합니다. 인공지능은 인간의 지능을 모방하기 위해 다양한 알고리즘과 기술을 사용합니다. 인공지능은

# %% [markdown]
# #요약

# %%
# 프롬프트 준비
prompt = '''아래 문장을 짧은 한 문장으로 요약해 주세요.

OpenAI는 영리법인 OpenAI LP와 그 모회사인 비영리법인 OpenAI Inc.로 구성된 인공지능 연구소입니다.
 2015년 말에 샘 알트만과 일론 머스크 등이 샌프란시스코에서 설립했습니다. 인류 전체에 도움이 되는 방식으로 친근한
 인공지능을 보급하고 발전시키는 것을 목표로 삼고 있습니다.'''

# %%
import openai

#텍스트 생성 실행
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0,
    max_tokens=500
)
print(response["choices"][0]["text"])
# Out:
# OpenAI는 샘 알트만과 일론 머스크 등이 설립한 인공지능 연구소로, 인류 전체에 도움이 되는 친근한 인공지능 보급 및 발전을 목표로 하고 있습니다.

# %% [markdown]
# # 번역

# %%
#프롬프트 준비
prompt = '''한국어를 영어로 번역합니다.

한국어: 나는 고양이다.
영어:'''

# %%
import openai

#텍스트 생성 실행
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0,
)
print(response["choices"][0]["text"])
# Out:
#  I am a cat.

# %% [markdown]
# #프로그램 생성

# %%
#프롬프트 준비
prompt = '''#  "Hello World!" 표시
def helloworld():
'''

# %%
import openai

#테스트 생성 실행
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt,
    temperature=0,
)
print(response["choices"][0]["text"])
# Out:
#     print("Hello World!")
#
# helloworld()

# %% [markdown]
# #채팅

# %%
#채팅 메시지 리스트 준비
messages = [
    {"role": "system", "content": "아카네는 여고생 여동생 캐릭터의 채팅 AI입니다. 남동생과 대화합니다."},
    {"role": "user", "content": "안녕!"},
]

# %%
import openai

#채팅 실행
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
    temperature=0,
)
response["choices"][0]["message"]["content"]
# Out:
# '안녕! 어떻게 지냈어? 무슨 일 있었어?'

# %%
print(response)
# Out:
# {
#   "id": "chatcmpl-8HtuSVHlel9s80CWSOPRgRtIA5Ajc",
#   "object": "chat.completion",
#   "created": 1699277184,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "\uc548\ub155! \uc5b4\ub5bb\uac8c \uc9c0\ub0c8\uc5b4? \ubb34\uc2a8 \uc77c \uc788\uc5c8\uc5b4?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 52,
#     "completion_tokens": 27,
#     "total_tokens": 79
#   }
# }

# %% [markdown]
# # 삽입

# %%
#프롬프트 준비
prefix_prompt = """def helloworld():
  '''
  설명: """

suffix_prompt = """
  '''
  print("Hello World!")

helloworld()
"""

# %%
import openai

#삽입 실행
response = openai.Completion.create(
    model="text-davinci-003",
    prompt=prefix_prompt,
    suffix=suffix_prompt,
    temperature=0.7,
    max_tokens=300
)
print(response["choices"][0]["text"])
# Out:
# Hello World 출력 함수
#   입력: 없음
#   리턴: 없음

# %% [markdown]
# # 편집

# %%
#프롬프트 준비
input = "오늘은 정말 즐거웠따."
instruction = "오타를 수정해 주세요."

# %%
import openai

#편집 실행
response = openai.Edit.create(
    model="text-davinci-edit-001", #코드의 경우 : code-davinci-edit-001
    input=input,
    instruction=instruction,
    temperature=0
)
print(response["choices"][0]["text"])
# Out:
# 오늘은 정말 즐거웠다.

# %%
print(response)
# Out:
# {
#   "object": "edit",
#   "created": 1699278042,
#   "choices": [
#     {
#       "text": "\uc624\ub298\uc740 \uc815\ub9d0 \uc990\uac70\uc6e0\ub2e4.\n",
#       "index": 0
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 66,
#     "completion_tokens": 64,
#     "total_tokens": 130
#   }
# }
