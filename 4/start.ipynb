# %%
#구글 드라이브 마운트
from google.colab import drive
drive.mount("/content/drive")

#작업 폴더 생성 및 이동
import os
os.makedirs("/content/drive/MyDrive/LangChain_First/LangChain-Study/4", exist_ok = True)
# %cd "/content/drive/MyDrive/LangChain_First/LangChain-Study/4"
